# %%
import pdfplumber
from pdf2image import convert_from_path
import pytesseract
import google.generativeai as genai

# Configure your Gemini API key
genai.configure(api_key="AIzaSyCwufnQZIaQAo78zYauNHDoK94-7iqhSKE")  # Replace with your actual API key

def extract_text_from_pdf(pdf_file):
    text = ""
    with pdfplumber.open(pdf_file) as pdf:
        for page in pdf.pages:
            # Attempt to extract text directly
            extracted_text = page.extract_text()
            if extracted_text:  # If text is found, append it
                text += extracted_text + "\n"
            else:  # If no text found, use OCR
                images = convert_from_path(pdf_file, first_page=page.page_number, last_page=page.page_number)
                for image in images:
                    ocr_text = pytesseract.image_to_string(image)
                    text += ocr_text + "\n"
    return text

def analyze_with_gemini(text):
    model = genai.GenerativeModel("gemini-1.5-flash")
    response = model.generate_content(f"Analyze this newspaper article:\n\n{text}")
    
    # Extracting the generated content safely
    if hasattr(response, 'parts'):
        texts = [part.text for part in response.parts if hasattr(part, 'text')]
        return "\n".join(texts)
    return "No content generated."

# Example usage
pdf_file_path = "TOI Delhi 31-10.pdf"
extracted_text = extract_text_from_pdf(pdf_file_path)

# Analyze or summarize the extracted text using Gemini API
gemini_analysis = analyze_with_gemini(extracted_text)
print(gemini_analysis)
# Out:
# ## Analysis of the Newspaper Article:
#
# This newspaper article, likely from the "The Times of India" dated October 31, 2024, is a fascinating snapshot of Indian life and culture on the eve of Diwali. It offers insights into:
#
# **1. Politics and Governance:**
#
# * **Diwali Politics:**  The article highlights the use of Diwali as a political tool, with AAP and BJP engaging in a war of words over the Ayushman Bharat scheme.
# * **Caste Survey:** The Telangana High Court's directive to appoint a dedicated commission for the caste survey reflects the ongoing debate surrounding reservations in India.
# * **Property Registration:** The Delhi government's new "anywhere registration" scheme aims to improve transparency and curb corruption in the real estate sector.
# * **MCD Staff:** The AAP government announces salary and Diwali bonus payments for MCD employees, highlighting a shift in governance style.
# ...
